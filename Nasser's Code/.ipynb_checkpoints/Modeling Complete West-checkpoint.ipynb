# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn import preprocessing

# %%
west = pd.read_excel('WEST.xlsx').set_index('index').fillna(method='ffill')

# %%
west.index = pd.to_datetime(west.index).round('h')
west['WeekNumber'] = west.index.week

# %% [markdown]
# # Solar

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.plot(west.index[2000:2100], west['WEST_solar'][2000:2100], color=color)
ax1.set_ylabel('Solar Generation', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.plot(west.index[2000:2100], west['HourlyDryBulbTemperature'][2000:2100], color=color)
ax2.set_ylabel('Temperature', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
X = west.drop(west.columns[-4:-1], axis=1)
y = west['WEST_solar']

split = 0.99

X_train, X_test, y_train, y_test = X[:int(split*len(X))], X[int(split*len(X)):], y[:int(split*len(X))], y[int(split*len(X)):]

# %%
tree = RandomForestRegressor()
tree.fit(X_train,y_train)
score_tree = tree.score(X_test,y_test)
tree_predict = tree.predict(X_test)

# %%
r2_score(y_test, tree_predict)
# Out:
# 0.25462314415147247

# %%
y_pred = tree.predict(X)

# %%
plt.figure(figsize=(12, 8))
plt.plot(west.index[int(split*len(X)):], west['WEST_solar'][int(split*len(X)):], label = 'True')
plt.plot(west.index[int(split*len(X)):], y_pred[int(split*len(X)):], label = 'Predicted')
plt.legend()

# %%
feature_importance_df = pd.DataFrame({'Feature Importances': tree.feature_importances_, 'Features': X_train.columns.values})

feature_importance_df.sort_values('Feature Importances').plot.bar(x = 'Features', figsize = (7, 5), legend=False, title='Feature Importances');

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)
y_pred = lm.predict(X)

# %%
r2_score(y, y_pred)
# Out:
# 0.37088176799939343

# %%
coefs = pd.concat([pd.DataFrame(X.columns), pd.DataFrame(np.transpose(lm.coef_), columns = ['Coefficients'])], axis = 1)
coefs = coefs.set_index(0)

# %%
coefs.sort_values('Coefficients', ascending = False)
# Out:
#                            Coefficients
# 0
# HourlyStationPressure         22.588944
# HourlyDryBulbTemperature       1.058477
# HourlyWindSpeed                0.550391
# WeekNumber                     0.087102
# HourlyWindDirection           -0.008828
# HourlyWindGustSpeed           -0.223469
# HourlyRelativeHumidity        -0.259951
# HourlyDewPointTemperature     -0.622926
# HourlyVisibility              -0.641666

# %%
plt.figure(figsize=(12, 8))
plt.plot(west.index[int(split*len(X)):], west['WEST_solar'][int(split*len(X)):], label = 'True')
plt.plot(west.index[int(split*len(X)):], y_pred[int(split*len(X)):], label = 'Predicted')
plt.legend()

# %% [markdown]
# # Wind

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.plot(west.index[2000:2100], west['WEST_wind'][2000:2100], color=color)
ax1.set_ylabel('Wind Generation', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.plot(west.index[2000:2100], west['HourlyWindSpeed'][2000:2100], color=color)
ax2.set_ylabel('Wind Speed', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
X = west.drop(west.columns[-4:-1], axis=1)
y = west['WEST_wind']

split = 0.99

X_train, X_test, y_train, y_test = X[:int(split*len(X))], X[int(split*len(X)):], y[:int(split*len(X))], y[int(split*len(X)):]

# %%
tree = RandomForestRegressor()
tree.fit(X_train,y_train)
score_tree = tree.score(X_test,y_test)
tree_predict = tree.predict(X_test)

# %%
r2_score(y_test, tree_predict)
# Out:
# -1.582387468563907

# %%
y_pred = tree.predict(X)

# %%
plt.figure(figsize=(12, 8))
plt.plot(west.index[int(split*len(X)):], west['WEST_wind'][int(split*len(X)):], label = 'True')
plt.plot(west.index[int(split*len(X)):], y_pred[int(split*len(X)):], label = 'Predicted')
plt.legend()

# %%
feature_importance_df = pd.DataFrame({'Feature Importances': tree.feature_importances_, 'Features': X_train.columns.values})

feature_importance_df.sort_values('Feature Importances').plot.bar(x = 'Features', figsize = (7, 5), legend=False, title='Feature Importances');

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)
y_pred = lm.predict(X)

# %%
r2_score(y, y_pred)
# Out:
# 0.2518754562219436

# %%
coefs = pd.concat([pd.DataFrame(X.columns), pd.DataFrame(np.transpose(lm.coef_), columns = ['Coefficients'])], axis = 1)
coefs = coefs.set_index(0)

# %%
coefs.sort_values('Coefficients', ascending = False)
# Out:
#                            Coefficients
# 0
# HourlyWindSpeed              117.788838
# HourlyDryBulbTemperature      88.962329
# HourlyRelativeHumidity        51.694083
# HourlyVisibility              43.229317
# HourlyWindGustSpeed           10.077514
# WeekNumber                     4.728710
# HourlyWindDirection           -0.917612
# HourlyDewPointTemperature   -135.334487
# HourlyStationPressure      -2336.944130

# %%
plt.figure(figsize=(12, 8))
plt.plot(west.index[int(split*len(X)):], west['WEST_wind'][int(split*len(X)):], label = 'True')
plt.plot(west.index[int(split*len(X)):], y_pred[int(split*len(X)):], label = 'Predicted')
plt.legend()

# %% [markdown]
# # Demand

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.plot(west.index[2000:2100], west['WEST_demand'][2000:2100], color=color)
ax1.set_ylabel('Total Demand', color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.plot(west.index[2000:2100], west['HourlyDryBulbTemperature'][2000:2100], color=color)
ax2.set_ylabel('Temperature', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
X = west.drop(west.columns[-4:-1], axis=1)
y = west['WEST_demand']

split = 0.99

X_train, X_test, y_train, y_test = X[:int(split*len(X))], X[int(split*len(X)):], y[:int(split*len(X))], y[int(split*len(X)):]

# %%
tree = RandomForestRegressor()
tree.fit(X_train,y_train)
score_tree = tree.score(X_test,y_test)
tree_predict = tree.predict(X_test)

# %%
r2_score(y_test, tree_predict)
# Out:
# -2.101086923777517

# %%
y_pred = tree.predict(X)

# %%
plt.figure(figsize=(12, 8))
plt.plot(west.index[int(split*len(X)):], west['WEST_demand'][int(split*len(X)):], label = 'True')
plt.plot(west.index[int(split*len(X)):], y_pred[int(split*len(X)):], label = 'Predicted')
plt.legend()

# %%
feature_importance_df = pd.DataFrame({'Feature Importances': tree.feature_importances_, 'Features': X_train.columns.values})

feature_importance_df.sort_values('Feature Importances').plot.bar(x = 'Features', figsize = (7, 5), legend=False, title='Feature Importances');

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)
y_pred = lm.predict(X)

# %%
r2_score(y, y_pred)
# Out:
# 0.16742530069921535

# %%
coefs = pd.concat([pd.DataFrame(X.columns), pd.DataFrame(np.transpose(lm.coef_), columns = ['Coefficients'])], axis = 1)
coefs = coefs.set_index(0)

# %%
coefs.sort_values('Coefficients', ascending = False)
# Out:
#                            Coefficients
# 0
# HourlyStationPressure       7563.815728
# HourlyDewPointTemperature   1055.259209
# HourlyWindGustSpeed           98.289914
# HourlyWindDirection            7.552879
# WeekNumber                   -49.225558
# HourlyWindSpeed              -66.455601
# HourlyVisibility            -186.815544
# HourlyRelativeHumidity      -536.786002
# HourlyDryBulbTemperature    -900.868266

# %%
plt.figure(figsize=(12, 8))
plt.plot(west.index[int(split*len(X)):], west['WEST_demand'][int(split*len(X)):], label = 'True')
plt.plot(west.index[int(split*len(X)):], y_pred[int(split*len(X)):], label = 'Predicted')
plt.legend()
